# %% [markdown]
# # Módulo 2. Análisis de datos
#
#
#
# # 3. Visualización de datos
#
# ### Manuel Castillo-Cara
# ### Machine Learning con Python

# %%
# Permite ajustar la anchura de la parte útil de la libreta (reduce los márgenes)
from IPython.core.display import display, HTML
display(HTML("<style>.container{ width:98% }</style>"))
# Out:
# <style>.container{ width:98% }</style>

# %% [markdown]
# # 1. Introducción

# %% [markdown]
# Lo primero que debemos realizar a la hora de trabajar con machine learning es visualizar nuestros datos para conocer su comportamiento y distribución. Esta primera observación de datos posibilita aprender más sobre ellos siendo la forma más rápida y útil de conocer qué técnicas son las más adecuadas en _pre_ y _pos_ procesamiento. En este sentido en esta tercera sección trabajaremos:
# * Cómo crear gráficos para entender cada atributo de manera independiente.
# * Cómo crear gráficos para entender las relaciones entre los diferentes atributos.
#
# Los gráficos de las relaciones entre los atributos pueden darnos una idea de los atributos que pueden ser redundantes, los métodos de remuestreo que pueden ser necesarios y, en última instancia, la dificultad de un problema de predicción. Para ello, la fase de visualización puede dividirse en las siguientes partes:
# * **Visualización univariable**: Cuando queremos visualizar un atributo de manera independiente a los demás.
# * **Visualización multivariable**: Cuando queremos visualizar la interacción entre los diferentes atributos de nuestro conjunto de datos.

# %% [markdown]
# # 1.1. Cargar el conjunto de datos

# %% [markdown]
# Para esta práctica vamos a cargar el conjunto de datos de Pima Indian Diabetes para hacer observaciones con las funciones de estadística descriptiva.

# %%
import pandas as pd
filename = 'data/pima-indians-diabetes.csv'
names = ['preg','plas','pres','skin','test','mass','pedi','age','class']
data = pd.read_csv(filename, names= names)
data
# Out:
#      preg  plas  pres  skin  test  mass     pedi  age  class
# 0       6   148    72    35     0  33.6   627.00   50      1
# 1       1    85    66    29     0  26.6   351.00   31      0
# 2       8   183    64     0     0  23.3   672.00   32      1
# 3       1    89    66    23    94  28.1   167.00   21      0
# 4       0   137    40    35   168  43.1  2288.00   33      1
# 5       5   116    74     0     0  25.6   201.00   30      0
# 6       3    78    50    32    88  31.0   248.00   26      1
# 7      10   115     0     0     0  35.3   134.00   29      0
# 8       2   197    70    45   543  30.5   158.00   53      1
# 9       8   125    96     0     0   0.0   232.00   54      1
# 10      4   110    92     0     0  37.6   191.00   30      0
# 11     10   168    74     0     0  38.0   537.00   34      1
# 12     10   139    80     0     0  27.1  1441.00   57      0
# 13      1   189    60    23   846  30.1   398.00   59      1
# 14      5   166    72    19   175  25.8   587.00   51      1
# 15      7   100     0     0     0  30.0   484.00   32      1
# 16      0   118    84    47   230  45.8   551.00   31      1
# 17      7   107    74     0     0  29.6   254.00   31      1
# 18      1   103    30    38    83  43.3   183.00   33      0
# 19      1   115    70    30    96  34.6   529.00   32      1
# 20      3   126    88    41   235  39.3   704.00   27      0
# 21      8    99    84     0     0  35.4   388.00   50      0
# 22      7   196    90     0     0  39.8   451.00   41      1
# 23      9   119    80    35     0  29.0   263.00   29      1
# 24     11   143    94    33   146  36.6   254.00   51      1
# 25     10   125    70    26   115  31.1   205.00   41      1
# 26      7   147    76     0     0  39.4   257.00   43      1
# 27      1    97    66    15   140  23.2   487.00   22      0
# 28     13   145    82    19   110  22.2   245.00   57      0
# 29      5   117    92     0     0  34.1   337.00   38      0
# ..    ...   ...   ...   ...   ...   ...      ...  ...    ...
# 738     2    99    60    17   160  36.6   453.00   21      0
# 739     1   102    74     0     0  39.5   293.00   42      1
# 740    11   120    80    37   150  42.3   785.00   48      1
# 741     3   102    44    20    94  30.8     0.40   26      0
# 742     1   109    58    18   116  28.5   219.00   22      0
# 743     9   140    94     0     0  32.7   734.00   45      1
# 744    13   153    88    37   140  40.6  1174.00   39      0
# 745    12   100    84    33   105  30.0   488.00   46      0
# 746     1   147    94    41     0  49.3   358.00   27      1
# 747     1    81    74    41    57  46.3  1096.00   32      0
# 748     3   187    70    22   200  36.4   408.00   36      1
# 749     6   162    62     0     0  24.3   178.00   50      1
# 750     4   136    70     0     0  31.2  1182.00   22      1
# 751     1   121    78    39    74  39.0   261.00   28      0
# 752     3   108    62    24     0  26.0   223.00   25      0
# 753     0   181    88    44   510  43.3   222.00   26      1
# 754     8   154    78    32     0  32.4   443.00   45      1
# 755     1   128    88    39   110  36.5  1057.00   37      1
# 756     7   137    90    41     0  32.0   391.00   39      0
# 757     0   123    72     0     0  36.3   258.00   52      1
# 758     1   106    76     0     0  37.5   197.00   26      0
# 759     6   190    92     0     0  35.5   278.00   66      1
# 760     2    88    58    26    16  28.4   766.00   22      0
# 761     9   170    74    31     0  44.0   403.00   43      1
# 762     9    89    62     0     0  22.5   142.00   33      0
# 763    10   101    76    48   180  32.9   171.00   63      0
# 764     2   122    70    27     0  36.8     0.34   27      0
# 765     5   121    72    23   112  26.2   245.00   30      0
# 766     1   126    60     0     0  30.1   349.00   47      1
# 767     1    93    70    31     0  30.4   315.00   23      0
#
# [768 rows x 9 columns]

# %% [markdown]
# #  2. Visualización Univariable

# %% [markdown]
# Como se ha comentado anteriormente, las gráficas univariable nos permiten visualizar los atributos individuales sin interacciones; las cuales, el objetivo principal de las mismas es aprender algo sobre la distribución, la tendencia y la propagación de cada atributo.
#
# A continuación se describen las más relevantes.

# %% [markdown]
# # 2.1. Histogramas

# %% [markdown]
# A partir de la forma de los contenedores, puede tener una idea rápida de si un atributo es gaussiano, sesgado o incluso tiene una distribución exponencial. También puede ayudarlo a ver posibles valores atípicos, por lo que [Matplotlib](https://www.datacamp.com/community/tutorials/histograms-matplotlib) es una pontente librería de visualización de datos

# %%
# %matplotlib inline
# Univariate Histograms
import matplotlib.pyplot as ptl
fig = ptl.figure(figsize = (10,10) )  # crear nuestra figura con su tamaño de 10x10
ax = fig.gca() # para agrandar la figura 
data.hist(ax= ax)
ptl.show()
# fijate que los graficos no estan en la misma escala pero se puede hacer un escalamiento
# Out:
# C:\Users\Usuario simple\python\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3325: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# Podemos ver que quizás los atributos `age`, `pedi` y `test` pueden tener una distribución exponencial. También podemos ver que quizás los atributos `mass`, `pres` y `plas` pueden tener una distribución gaussiana o casi gaussiana. Esto es interesante porque muchas técnicas de aprendizaje automático suponen una distribución univariada gaussiana en las variables de entrada.
#
# Esta misma representación puede verse con el paquete [Seaborn](https://seaborn.pydata.org/tutorial/distributions.html). Seaborn es un paquete de visualización más profesional que Matplotlib, además de usar este por debajo. Podemos ver los Histogramas con una línea de densidad que nos muestra su distribución

# %%
# %matplotlib inline
# Univariate Histograms
import matplotlib.pyplot as plt
import seaborn as sms
f, axes = plt.subplots(3,3 , figsize = (14,14)) # asignacion multiple . matriz de 3x3 y que el tamaño sea igual a 14
# tenemos que ir dibujando cada uno de los atributos linea a linea . 
sms.distplot(data['preg'], ax = axes[0,0] )
sms.distplot(data['plas'], ax = axes[0,1] )
sms.distplot(data['pres'], ax = axes[0,2] )
sms.distplot(data['skin'], ax = axes[1,0] )
sms.distplot(data['test'], ax = axes[1,1] )
sms.distplot(data['mass'], ax = axes[1,2] )
sms.distplot(data['pedi'], ax = axes[2,0] )
sms.distplot(data['age'], ax = axes[2,1] )
sms.distplot(data['class'], ax = axes[2,2] )

# %% [markdown]
# # 2.2. Densidad

# %% [markdown]
# Las gráficas se ven como un histograma abstracto con una curva suave dibujada a través de la parte superior de cada contenedor, al igual que su ojo intentó hacer con los histogramas. Podemos ver que la distribución de cada atributo es más clara que los histogramas

# %%
# %matplotlib inline
# Univariate Histograms
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (16,16) )
ax = fig.gca()
# le decimos que sea de tipo densidad , subplots (para representar en malla) ,
#  layout(en una matriz de 3x3
data.plot(ax = ax, kind = 'density', subplots = True ,layout = (3,3), sharex = False)
plt.show()
# Out:
# C:\Users\Usuario simple\python\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1801: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   plot_obj.generate()

# %% [markdown]
# Al igual que hemos visto antes podemos ver también el gráfico con la libreria Seaborn

# %%
# %matplotlib inline
# Univariate Histograms
import matplotlib.pyplot as plt
import seaborn as sms
f, axes = plt.subplots(3,3 , figsize = (14,14)) # asignacion multiple . matriz de 3x3 y que el tamaño sea igual a 14
# tenemos que ir dibujando cada uno de los atributos linea a linea . 
sms.distplot(data['preg'], hist = False , rug = True ,ax = axes[0,0] )
sms.distplot(data['plas'], hist = False , rug = True , ax = axes[0,1] )
sms.distplot(data['pres'], hist = False , rug = True , ax = axes[0,2] )
sms.distplot(data['skin'],  hist = False , rug = True ,ax = axes[1,0] )
sms.distplot(data['test'], hist = False , rug = True , ax = axes[1,1] )
sms.distplot(data['mass'],  hist = False , rug = True ,ax = axes[1,2] )
sms.distplot(data['pedi'],  hist = False , rug = True ,ax = axes[2,0] )
sms.distplot(data['age'],  hist = False , rug = True ,ax = axes[2,1] )
sms.distplot(data['class'],  hist = False , rug = True ,ax = axes[2,2] )

# %% [markdown]
# # 2.3. Boxplots

# %% [markdown]
# Podemos ver que la extensión de los atributos es bastante diferente. Algunos como la `age`, `test` y `skin` parecen bastante sesgados hacia valores más pequeños.

# %%
# %matplotlib inline
# Univariate Boxplot
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (13,13) )
ax = fig.gca()
# le decimos que sea de tipo densidad , subplots (para representar en malla) ,
#  layout(en una matriz de 3x3
data.plot(ax = ax, kind = 'box', subplots = True ,layout = (3,3), sharex = False)
plt.show()

# %%
# %matplotlib inline
# Univariate Boxplots
import matplotlib.pyplot as plt
import seaborn as sms
f, axes = plt.subplots(3,3 , figsize = (14,14)) # asignacion multiple . matriz de 3x3 y que el tamaño sea igual a 14
# tenemos que ir dibujando cada uno de los atributos linea a linea . 
sms.boxplot(data['preg'], ax = axes[0,0] )
sms.boxplot(data['plas'], ax = axes[0,1] )
sms.boxplot(data['pres'], ax = axes[0,2] )
sms.boxplot(data['skin'], ax = axes[1,0] )
sms.boxplot(data['test'], ax = axes[1,1] )
sms.boxplot(data['mass'], ax = axes[1,2] )
sms.boxplot(data['pedi'], ax = axes[2,0] )
sms.boxplot(data['age'], ax = axes[2,1] )
sms.boxplot(data['class'], ax = axes[2,2] )

# %% [markdown]
# #  3. Visualización Multivariable

# %% [markdown]
# Los gráficos multivariables son los gráficos en los que podemos analizar la relación o interacciones entre atributos. El objetivo es aprender algo acerca de la distribución, la tendencia y la distribución en grupos de datos, generalmente pares de atributos.

# %% [markdown]
# # 3.1. Matriz de correlación

# %% [markdown]
# Podemos ver que la matriz es simétrica, es decir, la parte inferior izquierda de la matriz es la misma que la parte superior derecha. Esto es útil ya que podemos ver dos vistas diferentes en los mismos datos en una parcela. También podemos ver que cada variable está perfectamente correlacionada positivamente entre sí (como era de esperar) en la línea diagonal desde la parte superior izquierda a la parte inferior derecha.

# %%
# %matplotlib inline
# Correlatioin matrix matplolib
import numpy as np 
import matplotlib.pyplot as plt
correlations = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin= -1 , vmax = 1)
fig. colorbar(cax)
ticks = np.arange(0,9,1) 
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()

# %% [markdown]
# Al igual que hemos visto antes podemos ver también el gráfico con la librería Seaborn

# %%
# %matplotlib inline
# Correlatioin matrix matplolib
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sms
correlation = data.corr()
plt.figure(figsize=(10,10))
ax = sms.heatmap(correlation, vmax = 1 , square = True , annot = True , cmap = 'viridis')
plt.title('Matriz de correlation')
plt.show()

# %% [markdown]
# # 3.2. Matriz de dispersión

# %% [markdown]
# Al igual que el diagrama de matriz de correlación anterior, la matriz de diagrama de dispersión es simétrica. Esto es útil para mirar las relaciones por pares desde diferentes perspectivas. Debido a que no tiene mucho sentido dibujar un diagrama de dispersión de cada variable consigo mismo, la diagonal muestra histogramas de cada atributo.

# %%
#!pip install pandas.tools
# ya no es necesario instalarlo , ya viene incluida

# %%
# %matplotlib inline
# Correlatioin matrix matplolib
from pandas.plotting import scatter_matrix
plt.rcParams['figure.figsize'] = [20,15]
scatter_matrix(data)
plt.show()

# %% [markdown]
# Al igual que hemos visto antes podemos ver también el gráfico con la librería Seaborn.

# %%
# %matplotlib inline
# Correlatioin matrix Seaborn
sms.pairplot(data)

# %% [markdown]
# # 3.3.  Matriz de dispersion por clase

# %% [markdown]
# Los puntos en una matriz de diagrama de dispersión pueden ser coloreados por la etiqueta de clase en problemas de clasificación. Esto puede ayudarnos a detectar una separación clara (o no clara) de las clases y quizás a darnos una idea de lo difícil que puede ser el problema.
#
# Al igual que el anterior gráfico los diagramas están dados por la interacción de los pares de atributos pero, en este caso, teniendo en cuenta la etiqueta clase.

# %%
# %matplotlib inline
# Correlatioin matrix Seaborn # unos puntos representan a una clase y otro a otra clase.
# lo idea seria tener objetos separdos y no superpuestos
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sms
sms.pairplot(data, hue = 'class', diag_kind ='hist')

# lo que nos interesa buscar si estas dos caracteristicas si estan separadas en claster .

# %% [markdown]
# # 3.4. Boxplots por clase

# %% [markdown]
# Este tipo de gráficos nos ayudan a comprender la superposición y la separación de la clase con los atributos características, por ejemplo en el gráfico podemos observar una buena separación de la clase _Setosa_ para el atributo _Petal.lenght_

# %%
# %matplotlib inline
# Boxplot for class
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sms

filename = 'data/iris.data.csv'
names = ['Sepal.lenght','Sepal.width','Petal.lenght','Petal.width','class']
data = pd.read_csv(filename, names= names)
plt.figure(1)
plt.subplots(figsize=(20,20))
plt.subplot(421)
sms.boxplot(x= 'class',y='Sepal.lenght', data = data)
plt.title('Sepal.lenght')
plt.grid(True)

plt.subplot(422)
sms.boxplot(x= 'class',y='Sepal.width', data = data)
plt.title('Sepal.width')
plt.grid(True)

plt.subplot(423)
sms.boxplot(x= 'class',y='Petal.lenght', data = data)
plt.title('Petal.lenght')
plt.grid(True)


plt.subplot(424)
sms.boxplot(x= 'class',y='Petal.width', data = data)
plt.title('Petal.width')
plt.grid(True)

plt.show()

# %% [markdown]
# <div style="text-align: right"> <font size=5>
#     <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a>
# </font></div>
#
# ---
#
# <div style="text-align: right"> <font size=6><i class="fa fa-coffee" aria-hidden="true" style="color:#004D7F"></i> </font></div>
